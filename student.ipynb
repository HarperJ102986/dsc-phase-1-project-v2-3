# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %%
# Your code here - remember to use markdown cells for comments as well!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
x = [1, 2, 3]
y = [1, 4, 9]
z = [10, 5, 0]
plt.plot(x, y)
plt.plot(x, z)
plt.title('Test Plot')
plt.xlabel('x')
plt.ylabel('y and z')
plt.legend(['This is y','This is z']) #takes list as arguement
plt.show()

# %%
del title_ratings

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_10',
#  '_12',
#  '_13',
#  '_15',
#  '_3',
#  '_5',
#  '_6',
#  '_7',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'exit',
#  'get_ipython',
#  'np',
#  'pd',
#  'plt',
#  'quit',
#  'sns',
#  'title_basics_df',
#  'title_ratings_df',
#  'x',
#  'y',
#  'z']

# %%
title_ratings_df = pd.read_csv('zippedData/imdb.title.ratings.csv.gz')

# %%
title_ratings_df.info()
title_ratings_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB
#        averagerating      numvotes
# count   73856.000000  7.385600e+04
# mean        6.332729  3.523662e+03
# std         1.474978  3.029402e+04
# min         1.000000  5.000000e+00
# 25%         5.500000  1.400000e+01
# 50%         6.500000  4.900000e+01
# 75%         7.400000  2.820000e+02
# max        10.000000  1.841066e+06

# %%
title_ratings.groupby('averagerating')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\JHARPE~1\AppData\Local\Temp/ipykernel_14588/306368016.py in <module>
# ----> 1 title_ratings.groupby('averagerating')
#
# NameError: name 'title_ratings' is not defined

# %%
movie_gross_df = pd.read_csv('zippedData/bom.movie_gross.csv.gz')

# %%
title_basics_df = pd.read_csv('zippedData/imdb.title.basics.csv.gz')

# %%
title_basics_df.rename(columns = {'primary_title': 'title'}, inplace = True)

# %%
title_basics_df.head()
# Out:
#       tconst                            title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
movie_title_df = pd.merge(movie_gross_df, title_basics_df, on = ['title'], how = 'left')

# %%
movie_title_df.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year     tconst       original_title  start_year  \
# 0     652000000  2010  tt0435761          Toy Story 3      2010.0
# 1     691300000  2010        NaN                  NaN         NaN
# 2     664300000  2010        NaN                  NaN         NaN
# 3     535700000  2010  tt1375666            Inception      2010.0
# 4     513900000  2010  tt0892791  Shrek Forever After      2010.0
#
#    runtime_minutes                      genres
# 0            103.0  Adventure,Animation,Comedy
# 1              NaN                         NaN
# ...

# %%
movie_title_df = pd.DataFrame({domestic_gross})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\JHARPE~1\AppData\Local\Temp/ipykernel_14588/3142785954.py in <module>
# ----> 1 movie_title_df = pd.DataFrame({domestic_gross})
#
# NameError: name 'domestic_gross' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\JHARPE~1\AppData\Local\Temp/ipykernel_14588/706674954.py in <module>
# ----> 1 head('domestic_gross')
#
# NameError: name 'head' is not defined

# %%
movie_title_df.sort_values(by = ['domestic_gross'], ascending = False).head(10)
# Out:
#                              title studio  domestic_gross foreign_gross  year  \
# 2262  Star Wars: The Force Awakens     BV     936700000.0       1,131.6  2015
# 3768                 Black Panther     BV     700100000.0     646900000  2018
# 3767        Avengers: Infinity War     BV     678800000.0       1,369.5  2018
# 2263                Jurassic World   Uni.     652300000.0       1,019.4  2015
# 882          Marvel's The Avengers     BV     623400000.0     895500000  2012
# 3351      Star Wars: The Last Jedi     BV     620200000.0     712400000  2017
# 3770                 Incredibles 2     BV     608600000.0     634200000  2018
# 2828  Rogue One: A Star Wars Story     BV     532200000.0     523900000  2016
# 3352   Beauty and the Beast (2017)     BV     504000000.0     759500000  2017
# 2829                  Finding Dory     BV     486300000.0     542300000  2016
#
#          tconst                           original_title  start_year  \
# ...

# %%
movie_title_df.head(20)
# Out:
#                                                 title studio  domestic_gross  \
# 0                                         Toy Story 3     BV     415000000.0
# 1                          Alice in Wonderland (2010)     BV     334200000.0
# 2         Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                           Inception     WB     292600000.0
# 4                                 Shrek Forever After   P/DW     238700000.0
# 5                          The Twilight Saga: Eclipse   Sum.     300500000.0
# 6                                          Iron Man 2   Par.     312400000.0
# 7                                             Tangled     BV     200800000.0
# 8                                       Despicable Me   Uni.     251500000.0
# 9                            How to Train Your Dragon   P/DW     217600000.0
# 10                         Clash of the Titans (2010)     WB     163200000.0
# ...

# %%
x = 'title'
y = movie_title_df.sort_values(by = ['domestic_gross']).head(10)
movie_title_df.plot(x, y, kind = 'bar') 
plt.title('Test Plot')
plt.xlabel('Movie title')
plt.ylabel('Gross Revenue')
plt.show()

# %%
movie_title_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4147 entries, 0 to 4146
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            4147 non-null   object
#  1   studio           4142 non-null   object
#  2   domestic_gross   4112 non-null   float64
#  3   foreign_gross    2516 non-null   object
#  4   year             4147 non-null   int64
#  5   tconst           3366 non-null   object
#  6   original_title   3366 non-null   object
#  7   start_year       3366 non-null   float64
#  8   runtime_minutes  3198 non-null   float64
#  9   genres           3326 non-null   object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 356.4+ KB

# %%
movie_title_df.dropna(inplace=True)#removing null values
movie_title_df.head()
# Out:
#                         title studio  domestic_gross foreign_gross  year  \
# 0                 Toy Story 3     BV     415000000.0     652000000  2010
# 3                   Inception     WB     292600000.0     535700000  2010
# 4         Shrek Forever After   P/DW     238700000.0     513900000  2010
# 5  The Twilight Saga: Eclipse   Sum.     300500000.0     398000000  2010
# 6                  Iron Man 2   Par.     312400000.0     311500000  2010
#
#       tconst              original_title  start_year  runtime_minutes  \
# 0  tt0435761                 Toy Story 3      2010.0            103.0
# 3  tt1375666                   Inception      2010.0            148.0
# 4  tt0892791         Shrek Forever After      2010.0             93.0
# 5  tt1325004  The Twilight Saga: Eclipse      2010.0            124.0
# 6  tt1228705                  Iron Man 2      2010.0            124.0
#
#                        genres
# 0  Adventure,Animation,Comedy
# 3     Action,Adventure,Sci-Fi
# ...

# %%
#removing the null values after merge
movie_title_df.reset_index(inplace = True, drop = True)

# %%
movie_title_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1894 entries, 0 to 1893
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            1894 non-null   object
#  1   studio           1894 non-null   object
#  2   domestic_gross   1894 non-null   float64
#  3   foreign_gross    1894 non-null   object
#  4   year             1894 non-null   int64
#  5   tconst           1894 non-null   object
#  6   original_title   1894 non-null   object
#  7   start_year       1894 non-null   float64
#  8   runtime_minutes  1894 non-null   float64
#  9   genres           1894 non-null   object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 148.1+ KB

# %%
title_basics_df.describe()
# Out:
#           start_year  runtime_minutes
# count  146144.000000    114405.000000
# mean     2014.621798        86.187247
# std         2.733583       166.360590
# min      2010.000000         1.000000
# 25%      2012.000000        70.000000
# 50%      2015.000000        87.000000
# 75%      2017.000000        99.000000
# max      2115.000000     51420.000000

# %%
runtime_title_basics_df = title_basics_df[(title_basics_df['runtime_minutes']>=40) & (title_basics_df['runtime_minutes']<=240)]
runtime_title_basics_df.describe()
# Out:
#           start_year  runtime_minutes
# count  108987.000000    108987.000000
# mean     2014.375815        87.768183
# std         2.646618        24.223085
# min      2010.000000        40.000000
# 25%      2012.000000        73.000000
# 50%      2014.000000        88.000000
# 75%      2017.000000       100.000000
# max      2022.000000       240.000000

# %%
start_year_basics_df = runtime_title_basics_df[runtime_title_basics_df['start_year'] >= 2010].copy()

# %%
start_year_basics_df.shape
# Out:
# (108987, 6)

# %%
movie_gross.head()

# %%
domestic_movie_gross = movie_gross['domestic_gross']

# %%
domestic_movie_gross.head()

# %%
movie_gross.info()

# %%
for film in movie_gross['title'][:10]:
    print('Toy Story 3' == film)

# %%
# !pwd

# %%
# !ls zippedData
